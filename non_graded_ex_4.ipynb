# %% [markdown]
# Write a simple program for a card Role-Playing Game. Try to use only the concepts you have learned so far in the lectures.
#
# REQUIREMENTS:
#
# 1. Following are the different cards, with their characteristics, available to the player
#
# Name: Diablo
# Health: 100
# Attack: 90
# Defense: 60
#
# Name: Medusa
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Jester
# Health: 120
# Attack: 60
# Defense: 90
#
# Name: Troll
# Health: 150
# Attack: 40
# Defense: 94
#
# Name: Specter
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
#
# Name: Savage
# Health: 100
# Attack: 90
# Defense: 50
#
# Name: Marauder
# Health: 100
# Attack: 85
# Defense: 50
#
# Name: Wimp
# Health: 110
# Attack: 40
# Defense: 85
#
# Name: Sorcerer
# Health: 100
# Attack: 70
# Defense: 55
#
# 2. Store the above card details using a suitable data structure like list, tuple, dictionary, or any combination of these
# 3. From these cards, assign a random deck of 5 cards to both the player and the computer (opponent).
#     3.1. This should happen whenever a new game begins
# 4. Keep the game running for as long as there are cards in the player's deck or for as long as there are cards in the opponent's deck
#     4.1. Show all the cards that the player has in their deck
#     4.2. Assign a random card to the opponent, and show that to the player, along with the details of that card. Only the details of this random card must be shown.
#     4.3. Ask the player to pick a card from their own deck to fight the opponent's card.
#     4.4. If the attack value of the player's card is more than the health of opponent's card, then the player wins this round.
#     4.5. Otherwise, the player's card will fight with the opponent's card.
#         4.5.1. Calculate the damage the player's card does to the opponent's card. This calculation should take care of the fact that the opponent's card will first defend the attack using its 'Defense' value. And if there is no defense value, only then will the player's attack value will affect the opponent card's health.
#
#         e.g.,
#         Player card
#
#         Name: Wimp
#         Health: 110
#         Attack: 40
#         Defense: 85
#
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 55
#
#         If the Wimp attacks Sorcerer, first, it will only affect Sorcerer's 'Defense' value. Sorcerer's defense value will decrease by the the attack value of player's Wimp card. Therefore, after the attack, the defense value will change from 55 to 15, as 55 - 40 = 15. Therefore,
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 15
#
#         Now, if in the next round, Wimp attacks Sorcerer again, then Sorcerer's defense value will decrease to 0, but its health will also be affected. The health will be affected by 25 points, as 40 - 15 = 25. So, Sorcerer's health will now decrease from 100 to 75
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 75
#         Attack: 70
#         Defense: 0
#
#         Now, let's say in a later round, the player uses the Marauder card, which has an attack value of 85, and the computer is using Sorcerer, whose health value is 75.
#
#         In that case, Sorcerer will be defeated, as 85 > 75. When this happens, remove the Sorcerer card from the deck of the opponent.
#
#         Display properly all these changes to the player at every round, so that they know how their attacks affected the round and what they can do next.
#
#         DO NOT just show the card details. Write proper statements, describing the process, as you may have seen in the demonstration given by the teacher
#
#         4.5.2. After the user's turn, make sure all the card values adjusted accordingly, just as described above.
#         4.5.3. ONLY a card's 'Defense' and 'Health' value changes after an attack. And once the 'Health' value of a card reaches 0 or drops below it, that card MUST be removed from the deck.
#         4.5.4. After the player's turn, pause the second for some seconds, e.g., time.sleep(3) will pause the game for 3 seconds.
#     4.6. Display that now it's the opponent's turn.
#     4.7. Make sure there are cards available in opponent's deck. If there aren't, then the game ends and the player wins.
#     4.8. If there are still cards available in opponent's deck, draw a random card from the opponent's deck, and display its details to the player.
#     4.9. Then display the cards available in the player's deck.
#     4.10 Ask the user to pick one card from their own deck to fight the opponent's card.
#     4.11. REPEAT THE SAME LOGIC AS STATED FROM POINT 4.4 TO 4.5.3. But this time, from the perspective of the opponent.
#     4.12. After the opponent's turn is over, display that a new round will begin in some seconds.
# 5. If it's found that the opponent has no card in their deck, then display a message stating player is the winner, otherwise display that the opponent won.

# %%
import random
import time

# Card data: Name, Health, Attack, Defense
card_deck = [
    {'name': 'Diablo', 'health': 100, 'attack': 90, 'defense': 60},
    {'name': 'Medusa', 'health': 100, 'attack': 70, 'defense': 70},
    {'name': 'Jester', 'health': 120, 'attack': 60, 'defense': 90},
    {'name': 'Troll', 'health': 150, 'attack': 40, 'defense': 94},
    {'name': 'Specter', 'health': 100, 'attack': 70, 'defense': 70},
    {'name': 'Mist', 'health': 100, 'attack': 75, 'defense': 65},
    {'name': 'Savage', 'health': 100, 'attack': 90, 'defense': 50},
    {'name': 'Marauder', 'health': 100, 'attack': 85, 'defense': 50},
    {'name': 'Wimp', 'health': 110, 'attack': 40, 'defense': 85},
    {'name': 'Sorcerer', 'health': 100, 'attack': 70, 'defense': 55}
]

# Number of cards per deck for player and opponent
deck_size = 5

# Initialize player and opponent decks
player_deck = random.sample(card_deck, deck_size)
opponent_deck = random.sample(card_deck, deck_size)

def display_card(card):
    """Utility function to display card details."""
    print(f"\nCard Name: {card['name']}\nHealth: {card['health']}\nAttack: {card['attack']}\nDefense: {card['defense']}")

def fight(player_card, opponent_card):
    """Simulates a fight between player card and opponent card."""
    print(f"\n{player_card['name']} attacks {opponent_card['name']}!")

    # Player attacks first
    if player_card['attack'] > opponent_card['health']:
        print(f"{opponent_card['name']} has been defeated!")
        return 'opponent_defeated'
    else:
        # Player's attack reduces opponent's defense first, then health if defense is depleted
        if opponent_card['defense'] > 0:
            damage_to_defense = min(opponent_card['defense'], player_card['attack'])
            opponent_card['defense'] -= damage_to_defense
            remaining_attack = player_card['attack'] - damage_to_defense
        else:
            remaining_attack = player_card['attack']
        
        opponent_card['health'] -= remaining_attack

        print(f"{opponent_card['name']}'s health is now {opponent_card['health']}, defense is now {opponent_card['defense']}")

        if opponent_card['health'] <= 0:
            print(f"{opponent_card['name']} has been defeated!")
            return 'opponent_defeated'
    
    return 'continue'

def game_over(winner):
    """Displays game over message."""
    print(f"\nGame Over! {winner} wins!")

# Main game loop
while player_deck and opponent_deck:
    print("\n--- Player's Turn ---")
    print("Your deck:")
    for i, card in enumerate(player_deck):
        print(f"{i + 1}. {card['name']} (Health: {card['health']}, Attack: {card['attack']}, Defense: {card['defense']})")

    opponent_card = random.choice(opponent_deck)
    print("\nOpponent's card:")
    display_card(opponent_card)

    player_choice = int(input("\nChoose a card from your deck to fight (1-5): ")) - 1
    player_card = player_deck[player_choice]

    result = fight(player_card, opponent_card)

    if result == 'opponent_defeated':
        opponent_deck.remove(opponent_card)

    # Pause for effect
    time.sleep(2)

    if not opponent_deck:
        game_over('Player')
        break

    print("\n--- Opponent's Turn ---")
    opponent_card = random.choice(opponent_deck)
    player_card = random.choice(player_deck)

    print(f"\nOpponent is using {opponent_card['name']} to attack your {player_card['name']}!")

    result = fight(opponent_card, player_card)

    if result == 'opponent_defeated':
        player_deck.remove(player_card)

    if not player_deck:
        game_over('Opponent')
        break

    # Pause for effect before next round
    time.sleep(2)

# End of the game
if not player_deck:
    game_over('Opponent')
elif not opponent_deck:
    game_over('Player')
# Out:
# --- Player's Turn ---
# Your deck:
# 1. Marauder (Health: 100, Attack: 85, Defense: 50)
# 2. Specter (Health: 100, Attack: 70, Defense: 70)
# 3. Diablo (Health: 100, Attack: 90, Defense: 60)
# 4. Medusa (Health: 100, Attack: 70, Defense: 70)
# 5. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent's card:
#
# Card Name: Savage
# Health: 100
# Attack: 90
# Defense: 50
#
# Marauder attacks Savage!
# Savage's health is now 65, defense is now 0
#
# --- Opponent's Turn ---
#
# Opponent is using Savage to attack your Specter!
#
# Savage attacks Specter!
# Specter's health is now 80, defense is now 0
#
# --- Player's Turn ---
# Your deck:
# 1. Marauder (Health: 100, Attack: 85, Defense: 50)
# 2. Specter (Health: 80, Attack: 70, Defense: 0)
# 3. Diablo (Health: 100, Attack: 90, Defense: 60)
# 4. Medusa (Health: 100, Attack: 70, Defense: 70)
# 5. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent's card:
#
# Card Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
#
# Medusa attacks Mist!
# Mist's health is now 95, defense is now 0
#
# --- Opponent's Turn ---
#
# Opponent is using Wimp to attack your Specter!
#
# Wimp attacks Specter!
# Specter's health is now 40, defense is now 0
#
# --- Player's Turn ---
# Your deck:
# 1. Marauder (Health: 100, Attack: 85, Defense: 50)
# 2. Specter (Health: 40, Attack: 70, Defense: 0)
# 3. Diablo (Health: 100, Attack: 90, Defense: 60)
# 4. Medusa (Health: 100, Attack: 70, Defense: 70)
# 5. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent's card:
#
# Card Name: Savage
# Health: 65
# Attack: 90
# Defense: 0
#
# Specter attacks Savage!
# Savage has been defeated!
#
# --- Opponent's Turn ---
#
# Opponent is using Specter to attack your Medusa!
#
# Specter attacks Medusa!
# Medusa's health is now 100, defense is now 0
#
# --- Player's Turn ---
# Your deck:
# 1. Marauder (Health: 100, Attack: 85, Defense: 50)
# 2. Specter (Health: 40, Attack: 70, Defense: 0)
# 3. Diablo (Health: 100, Attack: 90, Defense: 60)
# 4. Medusa (Health: 100, Attack: 70, Defense: 0)
# 5. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent's card:
#
# Card Name: Wimp
# Health: 110
# Attack: 40
# Defense: 85
#
# Jester attacks Wimp!
# Wimp's health is now 110, defense is now 25
#
# --- Opponent's Turn ---
#
# Opponent is using Wimp to attack your Diablo!
#
# Wimp attacks Diablo!
# Diablo's health is now 100, defense is now 20
#
# --- Player's Turn ---
# Your deck:
# 1. Marauder (Health: 100, Attack: 85, Defense: 50)
# 2. Specter (Health: 40, Attack: 70, Defense: 0)
# 3. Diablo (Health: 100, Attack: 90, Defense: 20)
# 4. Medusa (Health: 100, Attack: 70, Defense: 0)
# 5. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent's card:
#
# Card Name: Specter
# Health: 40
# Attack: 70
# Defense: 0
#
# Specter attacks Specter!
# Specter has been defeated!
#
# --- Opponent's Turn ---
#
# Opponent is using Wimp to attack your Jester!
#
# Wimp attacks Jester!
# Jester's health is now 120, defense is now 50
#
# --- Player's Turn ---
# Your deck:
# 1. Marauder (Health: 100, Attack: 85, Defense: 50)
# 2. Specter (Health: 40, Attack: 70, Defense: 0)
# 3. Diablo (Health: 100, Attack: 90, Defense: 20)
# 4. Medusa (Health: 100, Attack: 70, Defense: 0)
# 5. Jester (Health: 120, Attack: 60, Defense: 50)
#
# Opponent's card:
#
# Card Name: Sorcerer
# Health: 100
# Attack: 70
# Defense: 55
#
# Diablo attacks Sorcerer!
# Sorcerer's health is now 65, defense is now 0
#
# --- Opponent's Turn ---
#
# Opponent is using Sorcerer to attack your Marauder!
#
# Sorcerer attacks Marauder!
# Marauder's health is now 80, defense is now 0
#
# --- Player's Turn ---
# Your deck:
# 1. Marauder (Health: 80, Attack: 85, Defense: 0)
# 2. Specter (Health: 40, Attack: 70, Defense: 0)
# 3. Diablo (Health: 100, Attack: 90, Defense: 20)
# 4. Medusa (Health: 100, Attack: 70, Defense: 0)
# 5. Jester (Health: 120, Attack: 60, Defense: 50)
#
# Opponent's card:
#
# Card Name: Sorcerer
# Health: 65
# Attack: 70
# Defense: 0
#
# Specter attacks Sorcerer!
# Sorcerer has been defeated!
#
# --- Opponent's Turn ---
#
# Opponent is using Mist to attack your Specter!
#
# Mist attacks Specter!
# Specter has been defeated!
#
# --- Player's Turn ---
# Your deck:
# 1. Marauder (Health: 80, Attack: 85, Defense: 0)
# 2. Diablo (Health: 100, Attack: 90, Defense: 20)
# 3. Medusa (Health: 100, Attack: 70, Defense: 0)
# 4. Jester (Health: 120, Attack: 60, Defense: 50)
#
# Opponent's card:
#
# Card Name: Wimp
# Health: 110
# Attack: 40
# Defense: 25
#
# Marauder attacks Wimp!
# Wimp's health is now 50, defense is now 0
#
# --- Opponent's Turn ---
#
# Opponent is using Wimp to attack your Diablo!
#
# Wimp attacks Diablo!
# Diablo's health is now 80, defense is now 0
#
# --- Player's Turn ---
# Your deck:
# 1. Marauder (Health: 80, Attack: 85, Defense: 0)
# 2. Diablo (Health: 80, Attack: 90, Defense: 0)
# 3. Medusa (Health: 100, Attack: 70, Defense: 0)
# 4. Jester (Health: 120, Attack: 60, Defense: 50)
#
# Opponent's card:
#
# Card Name: Mist
# Health: 95
# Attack: 75
# Defense: 0
#
# Marauder attacks Mist!
# Mist's health is now 10, defense is now 0
#
# --- Opponent's Turn ---
#
# Opponent is using Mist to attack your Marauder!
#
# Mist attacks Marauder!
# Marauder's health is now 5, defense is now 0
#
# --- Player's Turn ---
# Your deck:
# 1. Marauder (Health: 5, Attack: 85, Defense: 0)
# 2. Diablo (Health: 80, Attack: 90, Defense: 0)
# 3. Medusa (Health: 100, Attack: 70, Defense: 0)
# 4. Jester (Health: 120, Attack: 60, Defense: 50)
#
# Opponent's card:
#
# Card Name: Mist
# Health: 10
# Attack: 75
# Defense: 0
#
# Marauder attacks Mist!
# Mist has been defeated!
#
# --- Opponent's Turn ---
#
# Opponent is using Wimp to attack your Medusa!
#
# Wimp attacks Medusa!
# Medusa's health is now 60, defense is now 0
#
# --- Player's Turn ---
# Your deck:
# 1. Marauder (Health: 5, Attack: 85, Defense: 0)
# 2. Diablo (Health: 80, Attack: 90, Defense: 0)
# 3. Medusa (Health: 60, Attack: 70, Defense: 0)
# 4. Jester (Health: 120, Attack: 60, Defense: 50)
#
# Opponent's card:
#
# Card Name: Wimp
# Health: 50
# Attack: 40
# Defense: 0
#
# Diablo attacks Wimp!
# Wimp has been defeated!
#
# Game Over! Player wins!
#
# Game Over! Player wins!
